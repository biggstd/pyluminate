# %%
import pandas as pd
import json

# %%
def read_maximme(json_metadata_path, char_types):
    """Construct dataframes with the needed metadata attached."""

    # Open the file.
    with open(json_metadata_path, 'r') as f:
        metadata = json.load(f)

    # Create an empty list to append the paths to.
    data_path_list = []

    # Iterate through the studies.
    for studies in metadata['studies']:
        for assays in studies['assays']:
            for char in assays['characteristicCategories']:
                if char['characteristicType']['annotationValue'] in char_types:
                    for data_file in assays['dataFiles']:
                        data_path_list.append(data_file['name'])
    return data_path_list


def create_parse_merge_dataframes(path_list):
    """Takes a list of datafile paths converts them to pandas data frames,
    then moves the columns around in a way likely specific to maximes data
    outputs."""

    def create_pandas_df(path):
        # Read the csv file
        df = pd.read_csv(
            filepath_or_buffer=path,
            index_col=False,
            sep='\s+' # Split by whitespace
        )

        # Move the columns to deal with the leading hashtag
        df_mod = df[df.columns[:-1]]
        df_mod.columns = df.columns[1:]

        return df_mod

    # Create the holder list for the data frames to be merged:
    data_frame_list = []

    # Iterate through the paths provided
    for data_path in path_list:
        new_df = create_pandas_df(data_path)
        data_frame_list.append(new_df)

    return pd.concat(data_frame_list, ignore_index=True)

# %%
rdf_list = read_maximme('data/nmr_metadata.json', char_types=['Simulated RDF'])

# %%
def create_pandas_df(path):
    # Read the csv file
    df = pd.read_csv(
        filepath_or_buffer=path,
        index_col=False,
        sep='\s+' # Split by whitespace
    )

    # Move the columns to deal with the leading hashtag
    df_mod = df[df.columns[:-1]]
    df_mod.columns = df.columns[1:]

    return df_mod


def read_maximme_rdf(json_metadata_path, char_types):
    """Construct dataframes with the needed metadata attached."""

    # Open the file.
    with open(json_metadata_path, 'r') as f:
        metadata = json.load(f)

    # Create an empty list to append the paths to.
    data_frame_list = []

    # Iterate through the studies.
    for studies in metadata['studies']:
        for assays in studies['assays']:
            for char in assays['characteristicCategories']:
                if char['characteristicType']['termSource'] in char_types:
                    # We found a matching termSource, so get the annotationValue
                    dimer_type = char['characteristicType']['annotationValue']
                    for data_file in assays['dataFiles']:
                        # Create the new dataframe
                        new_data_frame = create_pandas_df(data_file['name'])
                        # Add the desired metadata to the data frame:
                        new_data_frame['dimer'] = dimer_type
                        data_frame_list.append(new_data_frame)
                        
    return pd.concat(data_frame_list, ignore_index=True)

# %%
df = read_maximme_rdf('data/nmr_metadata.json', char_types=['Aluminate Species'])

# %%
df
# Out:
#         r  RDF_Al-Ob  RDF_Al-Oh  RCN_Al-Ob  RCN_Al-Oh  \
# 0    0.00        0.0     0.0000        0.0     0.0000
# 1    0.02        0.0     0.0000        0.0     0.0000
# 2    0.04        0.0     0.0000        0.0     0.0000
# 3    0.06        0.0     0.0000        0.0     0.0000
# 4    0.08        0.0     0.0000        0.0     0.0000
# 5    0.10        0.0     0.0000        0.0     0.0000
# 6    0.12        0.0     0.0000        0.0     0.0000
# 7    0.14        0.0     0.0000        0.0     0.0000
# 8    0.16        0.0     0.0000        0.0     0.0000
# 9    0.18        0.0     0.0000        0.0     0.0000
(OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 776  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 777  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 778  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 779  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 780  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 781  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 782  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 783  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 784  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 785  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 786  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 787  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 788  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 789  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 790  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 791  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 792  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 793  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 794  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 795  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 796  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 797  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 798  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 799  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 800  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
# 801  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+
#
# [802 rows x 6 columns]

# %%
df.melt(
    id_vars=["r", 'dimer'],
    value_vars=['RDF_Al-Ob','RDF_Al-Oh', 'RCN_Al-Ob', 'RCN_Al-Oh'],
    value_name="inter atom distance",
    var_name="Atom Pair"
)
# Out:
#          r                                  dimer  Atom Pair  \
# 0     0.00   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 1     0.02   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 2     0.04   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 3     0.06   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 4     0.08   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 5     0.10   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 6     0.12   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 7     0.14   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 8     0.16   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 9     0.18   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 10    0.20   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 11    0.22   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 12    0.24   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 13    0.26   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 14    0.28   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 15    0.30   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 16    0.32   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 17    0.34   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 18    0.36   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 19    0.38   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 20    0.40   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 21    0.42   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 22    0.44   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 23    0.46   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 24    0.48   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 25    0.50   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 26    0.52   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 27    0.54   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 28    0.56   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# 29    0.58   (OH)3Al-O-Al(OH)32-+ 180 H2O + 2 Na+  RDF_Al-Ob
# ...    ...                                    ...        ...
# 3178  3.40  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3179  3.42  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3180  3.44  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3181  3.46  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3182  3.48  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3183  3.50  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3184  3.52  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3185  3.54  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3186  3.56  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3187  3.58  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3188  3.60  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3189  3.62  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3190  3.64  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3191  3.66  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3192  3.68  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3193  3.70  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3194  3.72  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3195  3.74  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3196  3.76  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3197  3.78  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3198  3.80  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3199  3.82  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3200  3.84  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3201  3.86  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3202  3.88  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3203  3.90  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3204  3.92  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3205  3.94  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3206  3.96  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
# 3207  3.98  (OH)2Al-O2-Al(OH)2- + 181 H2O + 2 Na+  RCN_Al-Oh
#
#       inter atom distance
# 0                  0.0000
# 1                  0.0000
# 2                  0.0000
# 3                  0.0000
# 4                  0.0000
# 5                  0.0000
# 6                  0.0000
# 7                  0.0000
# 8                  0.0000
# 9                  0.0000
# 10                 0.0000
# 11                 0.0000
# 12                 0.0000
# 13                 0.0000
# 14                 0.0000
# 15                 0.0000
# 16                 0.0000
# 17                 0.0000
# 18                 0.0000
# 19                 0.0000
# 20                 0.0000
# 21                 0.0000
# 22                 0.0000
# 23                 0.0000
# 24                 0.0000
# 25                 0.0000
# 26                 0.0000
# 27                 0.0000
# 28                 0.0000
# 29                 0.0000
# ...                   ...
# 3178               2.0000
# 3179               2.0021
# 3180               2.0042
# 3181               2.0078
# 3182               2.0140
# 3183               2.0258
# 3184               2.0357
# 3185               2.0521
# 3186               2.0713
# 3187               2.0976
# 3188               2.1238
# 3189               2.1577
# 3190               2.1996
# 3191               2.2395
# 3192               2.2900
# 3193               2.3581
# 3194               2.4420
# 3195               2.5291
# 3196               2.6217
# 3197               2.7180
# 3198               2.8160
# 3199               2.9112
# 3200               3.0134
# 3201               3.1192
# 3202               3.2161
# 3203               3.3192
# 3204               3.4251
# 3205               3.5304
# 3206               3.6221
# 3207               3.7008
#
# [3208 rows x 4 columns]
